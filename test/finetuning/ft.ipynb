# %%
# !autotrain llm --train \
    --project-name "Llama2-law-finetuning-da" \
    --model "TinyPixel/Llama-2-7B-bf16-sharded" \
    --data-path "../data" \
    --text-column "text" \
    --peft \
    --quantization "int4" \
    --lr 2e-4 \
    --batch-size 4 \
    --epochs 40 \
    --trainer sft \
    --block_size 2048 \
    --model_max_length 2048 \
    --logging_steps 1
# Out:
# > INFO    Running LLM
# ...
